# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset =pd.read_csv("iris_Modified.csv")
dataset.head(3)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
#sns.pairplot(data=dataset)
#plt.show()

# %%
import scipy.cluster.hierarchy as sc

# %%
plt.figure(figsize=(20,20))
sc.dendrogram(sc.linkage(dataset, method='single', metric='euclidean'))
plt.savefig("demo.jpg")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

# Instantiate the clustering model
ac = AgglomerativeClustering(n_clusters=2, linkage='single')

# Assuming 'dataset' contains your input data
# Make sure to pass only the numeric features of the dataset
dataset['predict'] = ac.fit_predict(dataset)

# %%
dataset.head(3)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  predict
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1

# %%
sns.pairplot(data=dataset,hue='predict')
plt.show()
